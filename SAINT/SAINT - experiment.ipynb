# %% [markdown]
# # Preliminaries

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !git clone https://github.com/ogunlao/saint.git
# Out:
# Cloning into 'saint'...
# remote: Enumerating objects: 664, done.
# remote: Total 664 (delta 0), reused 0 (delta 0), pack-reused 664
# Receiving objects: 100% (664/664), 17.00 MiB | 12.72 MiB/s, done.
# Resolving deltas: 100% (364/364), done.

# %%
# !pip install pytorch-lightning==1.3.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning==1.3.2
#   Downloading pytorch_lightning-1.3.2-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.7/805.7 kB 44.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.3.2) (1.22.4)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.3.2) (2.0.1+cu118)
# Requirement already satisfied: future>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.3.2) (0.18.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.3.2) (4.65.0)
# Collecting PyYAML<=5.4.1,>=5.1 (from pytorch-lightning==1.3.2)
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 23.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: fsspec[http]>=2021.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.3.2) (2023.4.0)
# Requirement already satisfied: tensorboard!=2.5.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.3.2) (2.12.2)
# Collecting torchmetrics>=0.2.0 (from pytorch-lightning==1.3.2)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 50.4 MB/s eta 0:00:00
# Collecting pyDeprecate==0.3.0 (from pytorch-lightning==1.3.2)
#   Downloading pyDeprecate-0.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.3.2) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2) (2.27.1)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (0.40.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->pytorch-lightning==1.3.2) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->pytorch-lightning==1.3.2) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->pytorch-lightning==1.3.2) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->pytorch-lightning==1.3.2) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->pytorch-lightning==1.3.2) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->pytorch-lightning==1.3.2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->pytorch-lightning==1.3.2) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->pytorch-lightning==1.3.2) (16.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.1 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 18.0 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2021.4.0->pytorch-lightning==1.3.2) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->pytorch-lightning==1.3.2) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard!=2.5.0,>=2.2.0->pytorch-lightning==1.3.2) (3.2.2)
# Building wheels for collected packages: PyYAML
#   Building wheel for PyYAML (pyproject.toml) ... done
#   Created wheel for PyYAML: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45658 sha256=07af87a1d1b94d24d54fa7c3a1e1ffc17e7f99550a8e5a3a4b10b71010c40c22
#   Stored in directory: /root/.cache/pip/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
# Successfully built PyYAML
# Installing collected packages: PyYAML, pyDeprecate, multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, torchmetrics, pytorch-lightning
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# Successfully installed PyYAML-5.4.1 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 pyDeprecate-0.3.0 pytorch-lightning-1.3.2 torchmetrics-0.11.4 yarl-1.9.2

# %%
# !pip3 install -r "/content/saint/requirements.txt"

# %%
# !pip install scikit-learn==0.24.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikit-learn==0.24.2
#   Downloading scikit-learn-0.24.2.tar.gz (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 89.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==0.24.2) (3.1.0)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (pyproject.toml) ... done
#   Created wheel for scikit-learn: filename=scikit_learn-0.24.2-cp310-cp310-linux_x86_64.whl size=24897260 sha256=a2ab8c8a2cbd4c81671516578245d96e9e2d76dbc0732b2d3096807d0cd0f9fa
#   Stored in directory: /root/.cache/pip/wheels/13/a4/68/4e78865652fa14db4a162b491e5138565f97646f9e1f2ab8cc
# Successfully built scikit-learn
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.10.1 requires scikit-learn>=1.0.2, but you have scikit-learn 0.24.2 which is incompatible.
# yellowbrick 1.5 requires scikit-learn>=1.0.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed scikit-learn-0.24.2

# %%
# !pip install scipy==1.5.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4.tar.gz (25.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.2/25.2 MB 37.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# !pip install tensorboard==2.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboard==2.4.1
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 34.8 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (1.54.0)
# Collecting google-auth<2,>=1.6.3 (from tensorboard==2.4.1)
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 20.2 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard==2.4.1)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (3.4.3)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (1.22.4)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (67.7.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (1.16.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.4.1) (0.40.0)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2,>=1.6.3->tensorboard==2.4.1)
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.4.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<2,>=1.6.3->tensorboard==2.4.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.4.1) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.4.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.4.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.4.1) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.4.1) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard==2.4.1) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard==2.4.1) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.4.1) (3.2.2)
# Installing collected packages: cachetools, google-auth, google-auth-oauthlib, tensorboard
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.0
#     Uninstalling cachetools-5.3.0:
#       Successfully uninstalled cachetools-5.3.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.17.3
#     Uninstalling google-auth-2.17.3:
#       Successfully uninstalled google-auth-2.17.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.2
#     Uninstalling tensorboard-2.12.2:
#       Successfully uninstalled tensorboard-2.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.11.0 requires google-auth<3.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.17.3, but you have google-auth 1.35.0 which is incompatible.
# tensorflow 2.12.0 requires tensorboard<2.13,>=2.12, but you have tensorboard 2.4.1 which is incompatible.
# Successfully installed cachetools-4.2.4 google-auth-1.35.0 google-auth-oauthlib-0.4.6 tensorboard-2.4.1

# %%
# !pip install tensorboard-plugin-wit==1.8.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorboard-plugin-wit==1.8.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.2/781.2 kB 42.4 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit
#   Attempting uninstall: tensorboard-plugin-wit
#     Found existing installation: tensorboard-plugin-wit 1.8.1
#     Uninstalling tensorboard-plugin-wit-1.8.1:
#       Successfully uninstalled tensorboard-plugin-wit-1.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires tensorboard<2.13,>=2.12, but you have tensorboard 2.4.1 which is incompatible.
# Successfully installed tensorboard-plugin-wit-1.8.0

# %%
# !pip install torch==1.8.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement torch==1.8.1 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1)
# ERROR: No matching distribution found for torch==1.8.1

# %%
# !pip install torchmetrics==0.3.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics==0.3.2
#   Downloading torchmetrics-0.3.2-py3-none-any.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics==0.3.2) (2.0.1+cu118)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics==0.3.2) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.3.2) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.3.2) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.3.2) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.3.2) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.3.2) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.1->torchmetrics==0.3.2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.1->torchmetrics==0.3.2) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3.1->torchmetrics==0.3.2) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.1->torchmetrics==0.3.2) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.1->torchmetrics==0.3.2) (1.3.0)
# Installing collected packages: torchmetrics
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 0.11.4
#     Uninstalling torchmetrics-0.11.4:
#       Successfully uninstalled torchmetrics-0.11.4
# Successfully installed torchmetrics-0.3.2

# %%
# !pip install torchtext==0.6.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.27.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.0.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.16.0)
# Collecting sentencepiece (from torchtext==0.6.0)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.6.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchtext==0.6.0) (16.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.6.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.6.0) (1.3.0)
# Installing collected packages: sentencepiece, torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.2
#     Uninstalling torchtext-0.15.2:
#       Successfully uninstalled torchtext-0.15.2
# Successfully installed sentencepiece-0.1.99 torchtext-0.6.0

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.1+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)

# %%
# !pip install hydra-core
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hydra-core
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 12.1 MB/s eta 0:00:00
# Collecting omegaconf<2.4,>=2.2 (from hydra-core)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.0 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hydra-core) (23.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from omegaconf<2.4,>=2.2->hydra-core) (5.4.1)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=7d25ece5055f736b1ab52bc0caa3a2aee795d6310dc44315a5064e2c0e7c4d78
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf, hydra-core
# Successfully installed antlr4-python3-runtime-4.9.3 hydra-core-1.3.2 omegaconf-2.3.0

# %%
# !pip install ruamel_yaml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ruamel_yaml
#   Downloading ruamel.yaml-0.17.32-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 5.2 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel_yaml)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 35.5 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel_yaml
# Successfully installed ruamel.yaml.clib-0.2.7 ruamel_yaml-0.17.32

# %%
# !pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.10.1)
# Collecting scikit-learn>=1.0.2 (from imbalanced-learn)
#   Downloading scikit_learn-1.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 58.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.1.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# Successfully installed scikit-learn-1.2.2

# %%
# !pip install torch --upgrade torch
# !pip install torch --upgrade pytorch-lightning

# %%
# !nvcc --version

# %% [markdown]
# # IMPORTANT : EDIT FILE-FILE INI DULU SEBELUM RUN

# %% [markdown]
# Cara editnya : double-click file yg mau di edit di "Files" (tab kiri colab) ato klik link-link dibawah, terus ctrl-s buat save.
#
# ```1. /content/saint/configs/config.yaml, line 21```
#
# ```
# optimizer:
#   # parameter for contrastive loss
#   temperature: 0.7
#   proj_head_dim: 128
#
#   # parameters for training
#   beta_1: 0.9
#   beta_2: 0.99
#   lr: 0.0001
#   weight_decay: 0.01
#   optim: adamw
#   metric: acc
#
# preproc:
#   data_folder: null
#   train_split: 0.65
#   validation_split: 0.15
#   test_split: 0.20
#   num_supervised_train_data: null # {all 50 200 500}
#
# callback:
#   monitor: val_loss # {val_loss, val_auroc_epoch}
#   mode: min # {max, min}
#   auto_insert_metric_name: false
#
# trainer:
#   max_epochs: 10
#   gpus: 1
#   deterministic: true
#   default_root_dir: null
#   resume_from_checkpoint: null
# ```
#
# ```2. /content/saint/configs/data/bank_ssl.yaml, line 10```
# ```
# data_stats:
#   no_cat: 1
#   no_num: 49
#   cats: [1]
# ```
#
# ```3. /content/saint/configs/data/bank_sup.yaml, line 10```
#
# ```
# data_stats:
#   no_cat: 1
#   no_num: 49
#   cats: [1]
# ```
#
# ```4. /content/saint/configs/experiment/supervised.yaml```
#
# ```
# experiment: supervised
# task: classification
# model: saint
# num_output: 5
# freeze_encoder: false
# pretrained_checkpoint: null #checkpoints/lightning_logs/version_7/checkpoints/epoch=0-step=1.ckpt
# ```
#
# ```5. /content/saint/configs/experiment/self-supervised.yaml```
#
# ```
# experiment: self-supervised
# task: classification
# model: saint
# num_output: 5
# freeze_encoder: false
# pretrained_checkpoint: null #checkpoints/lightning_logs/version_7/checkpoints/epoch=0-step=1.ckpt
# ```
#
# ```4. /content/saint/configs/experiment/predict.yaml```
#
# ```
# model: saint
# task: classification
# pretrained_checkpoint: ?? #nulll
# num_output: 5
#
# pred_sav_path: ?? # path to save prediction e.g ""./prediction.csv"
# save_prediction: true
# id_col: index
# target_col: target
# ```

# %% [markdown]
# # Setting up parameters

# %%
import os

import numpy as np
import pandas as pd

from ruamel.yaml import YAML

import torch

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from matplotlib import pyplot as plt
import seaborn as sns

print(torch.cuda.is_available())
# Out:
# True

# %%
data_folder = "/content/saint/data"

os.mkdir("/content/saint/data")

# %%
config_path = 'saint/configs/config.yaml'

yaml = YAML(typ='safe')
with open(config_path) as f:
  args = yaml.load(f)

print(args)
# Out:
# {'defaults': ['_self_', {'experiment': 'supervised'}, {'data': 'bank_sup'}], 'seed': 1234, 'transformer': {'num_layers': 6, 'num_heads': 8, 'dropout': 0.1, 'dropout_ff': 0.1, 'embed_dim': 32, 'd_ff': 32, 'cls_token_idx': 0}, 'augmentation': {'prob_cutmix': 0.3, 'alpha': 0.2, 'lambda_pt': 10}, 'optimizer': {'temperature': 0.7, 'proj_head_dim': 128, 'beta_1': 0.9, 'beta_2': 0.99, 'lr': 0.0001, 'weight_decay': 0.01, 'optim': 'adamw', 'metric': 'acc'}, 'preproc': {'data_folder': None, 'train_split': 0.65, 'validation_split': 0.15, 'test_split': 0.2, 'num_supervised_train_data': None}, 'callback': {'monitor': 'val_loss', 'mode': 'min', 'auto_insert_metric_name': False}, 'trainer': {'max_epochs': 10, 'gpus': 1, 'deterministic': True, 'default_root_dir': None, 'resume_from_checkpoint': None}, 'dataloader': {'shuffle_val': False, 'train_bs': 32, 'val_bs': 32, 'test_bs': 16, 'num_workers': 2, 'pin_memory': False}, 'metric': '${optimizer.metric}', 'print_config': False}

# %% [markdown]
# # Data preprocessing

# %%
dataset = pd.read_csv("/content/drive/MyDrive/SEM4/Research Method/RM Kel 19 Experiment/data-final.csv", sep='\t')

print(dataset.shape)
dataset.head()
# Out:
# (1015341, 110)
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
#
#               dateload  screenw  screenh  introelapse  testelapse  endelapse  \
# 0  2016-03-03 02:01:01    768.0   1024.0          9.0       234.0          6
# 1  2016-03-03 02:01:20   1360.0    768.0         12.0       179.0         11
# 2  2016-03-03 02:01:56   1366.0    768.0          3.0       186.0          7
# 3  2016-03-03 02:02:02   1920.0   1200.0        186.0       219.0          7
# 4  2016-03-03 02:02:57   1366.0    768.0          8.0       315.0         17
#
#    IPC  country  lat_appx_lots_of_err  long_appx_lots_of_err
# 0    1       GB               51.5448                 0.1991
# 1    1       MY                3.1698                101.706
# 2    1       GB               54.9119                -1.3833
# 3    1       GB                 51.75                  -1.25
# 4    2       KE                   1.0                   38.0
#
# [5 rows x 110 columns]

# %%
dataset = dataset.drop(list(dataset)[50:], axis=1)

print(dataset.shape)
dataset.head()
# Out:
# (1015341, 50)
#    EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  OPN1  \
# 0   4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...   5.0
# 1   3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...   1.0
# 2   2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...   5.0
# 3   2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...   4.0
# 4   3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...   5.0
#
#    OPN2  OPN3  OPN4  OPN5  OPN6  OPN7  OPN8  OPN9  OPN10
# 0   1.0   4.0   1.0   4.0   1.0   5.0   3.0   4.0    5.0
# 1   2.0   4.0   2.0   3.0   1.0   4.0   2.0   5.0    3.0
# 2   1.0   2.0   1.0   4.0   2.0   5.0   3.0   4.0    4.0
# 3   2.0   5.0   2.0   3.0   1.0   4.0   4.0   3.0    3.0
# 4   1.0   5.0   1.0   5.0   1.0   5.0   3.0   5.0    5.0
#
# [5 rows x 50 columns]

# %%
for i in dataset.columns:
  dataset = dataset[(dataset[i].notna()) & (dataset[i] != 0)]

print(dataset.shape)
# Out:
# (874434, 50)

# %%
data = dataset.astype(int)

# %%
data = data[:62535]

# %%
x = data.drop(columns=['EST9'])
y = data['EST9']

# %%
class_counts = data['EST9'].value_counts()
data['EST9'].value_counts()
# Out:
# 4    18229
# 2    13743
# 3    13301
# 5     9914
# 1     7348
# Name: EST9, dtype: int64

# %%
plt.bar(class_counts.index, height=class_counts.values, width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Random undersampling

# %%
# from imblearn.under_sampling  import RandomUnderSampler

# undersampler = RandomUnderSampler(random_state=42)

# x, y = undersampler.fit_resample(x, y)

# %%
# y.value_counts()
# Out:
# 1    12507
# 2    12507
# 3    12507
# 4    12507
# 5    12507
# Name: EST9, dtype: int64

# %%
y = y - 1

# %%
y.shape
# Out:
# (62535,)

# %% [markdown]
# ## Splitting dataset

# %%
from saint.src.dataset import generate_splits, preprocess

# %%
num_supervised_train_data = 62535//2

sup_train_indices, val_indices, test_indices, ssl_train_indices = generate_splits(len(x), num_supervised_train_data, args['preproc']['validation_split'], args['preproc']['test_split'], args['seed'],)

# %%
x_proc, y_proc, no_num, no_cat, cats  = preprocess(x, y, args['transformer']['cls_token_idx'])

# %%
print('no of numerical columns: ', no_num)
print('no of categorical columns: ', no_cat)

print('list of categories in each categorical column: ', cats)
# Out:
# no of numerical columns:  49
# no of categorical columns:  1
# list of categories in each categorical column:  [1]

# %%
train_df, train_y   = x_proc.iloc[sup_train_indices], y_proc.iloc[sup_train_indices]
val_df, val_y       = x_proc.iloc[val_indices], y_proc.iloc[val_indices]
test_df, test_y     = x_proc.iloc[test_indices], y_proc.iloc[test_indices]

# %%
train_ssl, train_ssl_y = None, None

if num_supervised_train_data != 'all':
    train_ssl, train_ssl_y = x_proc.iloc[ssl_train_indices], y_proc.iloc[ssl_train_indices]

# %%
train_df.to_csv('/content/saint/data/train.csv' , index=False)
train_y.to_csv('/content/saint/data/train_y.csv' , index=False)
val_df.to_csv('/content/saint/data/val.csv' , index=False)
val_y.to_csv('/content/saint/data/val_y.csv' , index=False)
test_df.to_csv('/content/saint/data/test.csv' , index=False)
test_y.to_csv('/content/saint/data/test_y.csv' , index=False)

if train_ssl is not None:
   train_ssl.to_csv('/content/saint/data/train_ssl.csv' , index=False)

if train_ssl_y is not None:
  train_ssl_y.to_csv('/content/saint/data/train_ssl_y.csv' , index=False)

# %% [markdown]
# # SAINT training

# %%
num_gpus = 1

os.environ["HYDRA_FULL_ERROR"] = "1"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %% [markdown]
# ## Self-supervised learning + supervised learning

# %% [markdown]
# ### Self-supervised learning

# %%
# !python /content/saint/main.py experiment=self-supervised \
  experiment.model=saint \
  data.data_folder=/content/saint/data \
  data=bank_ssl
# Out:
# 2023-06-22 13:44:38.201373: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 13:44:39.223138: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/saint/main.py:11: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Global seed set to 1234
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type            | Params
# --------------------------------------------------------
# 0 | transformer         | Encoder         | 65.0 K
# 1 | embedding           | Embedding       | 3.2 K
# 2 | contrastive_loss_fn | ContrastiveLoss | 409 K
# 3 | denoising_loss_fn   | DenoisingLoss   | 1.6 K
# --------------------------------------------------------
# 479 K     Trainable params
# 0         Non-trainable params
# 479 K     Total params
# 1.918     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  51% 300/588 [01:01<00:58,  4.90it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 0:  54% 320/588 [01:02<00:52,  5.11it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  58% 340/588 [01:03<00:46,  5.33it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  61% 360/588 [01:05<00:41,  5.53it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  65% 380/588 [01:06<00:36,  5.73it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  68% 400/588 [01:07<00:31,  5.93it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  71% 420/588 [01:08<00:27,  6.10it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  75% 440/588 [01:10<00:23,  6.24it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  78% 460/588 [01:12<00:20,  6.37it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  82% 480/588 [01:13<00:16,  6.50it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  85% 500/588 [01:15<00:13,  6.65it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  88% 520/588 [01:16<00:09,  6.81it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  92% 540/588 [01:17<00:06,  6.96it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  95% 560/588 [01:18<00:03,  7.10it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0:  99% 580/588 [01:20<00:01,  7.24it/s, loss=586, v_num=0, val_loss_epoch=713.0, train_loss_step=582.0]
# Epoch 0: 100% 588/588 [01:21<00:00,  7.26it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=503.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  51% 300/588 [01:02<00:59,  4.82it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 1:  54% 320/588 [01:03<00:53,  5.01it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  58% 340/588 [01:05<00:47,  5.20it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  61% 360/588 [01:07<00:42,  5.35it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  65% 380/588 [01:08<00:37,  5.54it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  68% 400/588 [01:09<00:32,  5.72it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  71% 420/588 [01:11<00:28,  5.91it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  75% 440/588 [01:12<00:24,  6.08it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  78% 460/588 [01:13<00:20,  6.25it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  82% 480/588 [01:14<00:16,  6.41it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  85% 500/588 [01:16<00:13,  6.57it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  88% 520/588 [01:17<00:10,  6.73it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  92% 540/588 [01:18<00:07,  6.85it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  95% 560/588 [01:20<00:04,  6.97it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1:  99% 580/588 [01:22<00:01,  7.06it/s, loss=620, v_num=0, val_loss_epoch=600.0, train_loss_step=604.0, train_loss_epoch=602.0, val_loss_step=482.0]
# Epoch 1: 100% 588/588 [01:23<00:00,  7.06it/s, loss=587, v_num=0, val_loss_epoch=600.0, train_loss_step=342.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  51% 300/588 [01:02<00:59,  4.82it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 2:  54% 320/588 [01:03<00:53,  5.03it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  58% 340/588 [01:04<00:47,  5.24it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  61% 360/588 [01:06<00:41,  5.44it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  65% 380/588 [01:07<00:36,  5.64it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  68% 400/588 [01:08<00:32,  5.83it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  71% 420/588 [01:09<00:27,  6.01it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  75% 440/588 [01:11<00:24,  6.16it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  78% 460/588 [01:13<00:20,  6.29it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  82% 480/588 [01:14<00:16,  6.41it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  85% 500/588 [01:16<00:13,  6.57it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  88% 520/588 [01:17<00:10,  6.72it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  92% 540/588 [01:18<00:06,  6.87it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  95% 560/588 [01:19<00:03,  7.02it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2:  99% 580/588 [01:21<00:01,  7.16it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=598.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 2: 100% 588/588 [01:21<00:00,  7.17it/s, loss=586, v_num=0, val_loss_epoch=600.0, train_loss_step=472.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  51% 300/588 [01:02<01:00,  4.79it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 3:  54% 320/588 [01:04<00:53,  4.97it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  58% 340/588 [01:05<00:48,  5.15it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  61% 360/588 [01:07<00:42,  5.31it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  65% 380/588 [01:09<00:37,  5.50it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  68% 400/588 [01:10<00:33,  5.69it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  71% 420/588 [01:11<00:28,  5.87it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  75% 440/588 [01:12<00:24,  6.04it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  78% 460/588 [01:14<00:20,  6.21it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  82% 480/588 [01:15<00:16,  6.38it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  85% 500/588 [01:16<00:13,  6.54it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  88% 520/588 [01:17<00:10,  6.68it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  92% 540/588 [01:19<00:07,  6.80it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  95% 560/588 [01:20<00:04,  6.92it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3:  99% 580/588 [01:22<00:01,  7.01it/s, loss=594, v_num=0, val_loss_epoch=600.0, train_loss_step=608.0, train_loss_epoch=600.0, val_loss_step=482.0]
# Epoch 3: 100% 588/588 [01:23<00:00,  7.02it/s, loss=592, v_num=0, val_loss_epoch=600.0, train_loss_step=478.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  51% 300/588 [01:02<00:59,  4.82it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 4:  54% 320/588 [01:03<00:53,  5.03it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  58% 340/588 [01:04<00:47,  5.24it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  61% 360/588 [01:06<00:41,  5.45it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  65% 380/588 [01:07<00:36,  5.65it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  68% 400/588 [01:08<00:32,  5.83it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  71% 420/588 [01:10<00:28,  5.99it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  75% 440/588 [01:11<00:24,  6.14it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  78% 460/588 [01:13<00:20,  6.26it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  82% 480/588 [01:14<00:16,  6.41it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  85% 500/588 [01:16<00:13,  6.57it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  88% 520/588 [01:17<00:10,  6.72it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  92% 540/588 [01:18<00:06,  6.87it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  95% 560/588 [01:19<00:03,  7.02it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4:  99% 580/588 [01:21<00:01,  7.16it/s, loss=613, v_num=0, val_loss_epoch=600.0, train_loss_step=586.0, train_loss_epoch=600.0, val_loss_step=479.0]
# Epoch 4: 100% 588/588 [01:21<00:00,  7.17it/s, loss=602, v_num=0, val_loss_epoch=599.0, train_loss_step=459.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  51% 300/588 [01:03<01:00,  4.74it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 5:  54% 320/588 [01:05<00:54,  4.92it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  58% 340/588 [01:06<00:48,  5.08it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  61% 360/588 [01:08<00:43,  5.28it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  65% 380/588 [01:09<00:38,  5.47it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  68% 400/588 [01:10<00:33,  5.66it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  71% 420/588 [01:11<00:28,  5.84it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  75% 440/588 [01:13<00:24,  6.01it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  78% 460/588 [01:14<00:20,  6.18it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  82% 480/588 [01:15<00:17,  6.34it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  85% 500/588 [01:16<00:13,  6.50it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  88% 520/588 [01:18<00:10,  6.62it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  92% 540/588 [01:20<00:07,  6.75it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  95% 560/588 [01:21<00:04,  6.84it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5:  99% 580/588 [01:23<00:01,  6.98it/s, loss=595, v_num=0, val_loss_epoch=599.0, train_loss_step=597.0, train_loss_epoch=599.0, val_loss_step=485.0]
# Epoch 5: 100% 588/588 [01:24<00:00,  7.00it/s, loss=585, v_num=0, val_loss_epoch=598.0, train_loss_step=508.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  51% 300/588 [01:02<00:59,  4.80it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 6:  54% 320/588 [01:03<00:53,  5.01it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  58% 340/588 [01:05<00:47,  5.22it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  61% 360/588 [01:06<00:42,  5.43it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  65% 380/588 [01:07<00:37,  5.62it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  68% 400/588 [01:09<00:32,  5.78it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  71% 420/588 [01:10<00:28,  5.93it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  75% 440/588 [01:12<00:24,  6.06it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  78% 460/588 [01:13<00:20,  6.22it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  82% 480/588 [01:15<00:16,  6.38it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  85% 500/588 [01:16<00:13,  6.54it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  88% 520/588 [01:17<00:10,  6.70it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  92% 540/588 [01:18<00:07,  6.85it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  95% 560/588 [01:20<00:04,  6.99it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6:  99% 580/588 [01:21<00:01,  7.13it/s, loss=586, v_num=0, val_loss_epoch=598.0, train_loss_step=568.0, train_loss_epoch=599.0, val_loss_step=473.0]
# Epoch 6: 100% 588/588 [01:22<00:00,  7.15it/s, loss=581, v_num=0, val_loss_epoch=595.0, train_loss_step=420.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  51% 300/588 [01:03<01:00,  4.75it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 7:  54% 320/588 [01:05<00:54,  4.91it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  58% 340/588 [01:06<00:48,  5.11it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  61% 360/588 [01:07<00:42,  5.32it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  65% 380/588 [01:08<00:37,  5.51it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  68% 400/588 [01:10<00:33,  5.69it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  71% 420/588 [01:11<00:28,  5.88it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  75% 440/588 [01:12<00:24,  6.05it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  78% 460/588 [01:13<00:20,  6.22it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  82% 480/588 [01:15<00:16,  6.39it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  85% 500/588 [01:16<00:13,  6.52it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  88% 520/588 [01:18<00:10,  6.65it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  92% 540/588 [01:20<00:07,  6.75it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  95% 560/588 [01:21<00:04,  6.88it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7:  99% 580/588 [01:22<00:01,  7.02it/s, loss=595, v_num=0, val_loss_epoch=595.0, train_loss_step=690.0, train_loss_epoch=597.0, val_loss_step=469.0]
# Epoch 7: 100% 588/588 [01:23<00:00,  7.04it/s, loss=612, v_num=0, val_loss_epoch=593.0, train_loss_step=497.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  51% 300/588 [01:02<00:59,  4.81it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 8:  54% 320/588 [01:03<00:53,  5.01it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  58% 340/588 [01:05<00:47,  5.23it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  61% 360/588 [01:06<00:42,  5.43it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  65% 380/588 [01:07<00:37,  5.61it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  68% 400/588 [01:09<00:32,  5.77it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  71% 420/588 [01:11<00:28,  5.91it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  75% 440/588 [01:12<00:24,  6.06it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  78% 460/588 [01:13<00:20,  6.23it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  82% 480/588 [01:15<00:16,  6.40it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  85% 500/588 [01:16<00:13,  6.56it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  88% 520/588 [01:17<00:10,  6.71it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  92% 540/588 [01:18<00:06,  6.86it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  95% 560/588 [01:19<00:03,  7.01it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8:  99% 580/588 [01:21<00:01,  7.15it/s, loss=590, v_num=0, val_loss_epoch=593.0, train_loss_step=599.0, train_loss_epoch=596.0, val_loss_step=456.0]
# Epoch 8: 100% 588/588 [01:22<00:00,  7.15it/s, loss=586, v_num=0, val_loss_epoch=591.0, train_loss_step=386.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  51% 300/588 [01:03<01:01,  4.71it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 9:  54% 320/588 [01:05<00:54,  4.89it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  58% 340/588 [01:06<00:48,  5.10it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  61% 360/588 [01:07<00:43,  5.30it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  65% 380/588 [01:09<00:37,  5.50it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  68% 400/588 [01:10<00:33,  5.69it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  71% 420/588 [01:11<00:28,  5.87it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  75% 440/588 [01:12<00:24,  6.04it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  78% 460/588 [01:14<00:20,  6.21it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  82% 480/588 [01:15<00:16,  6.37it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  85% 500/588 [01:16<00:13,  6.50it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  88% 520/588 [01:18<00:10,  6.62it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  92% 540/588 [01:20<00:07,  6.72it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  95% 560/588 [01:21<00:04,  6.87it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9:  99% 580/588 [01:22<00:01,  7.01it/s, loss=592, v_num=0, val_loss_epoch=591.0, train_loss_step=586.0, train_loss_epoch=594.0, val_loss_step=462.0]
# Epoch 9: 100% 588/588 [01:23<00:00,  7.02it/s, loss=578, v_num=0, val_loss_epoch=589.0, train_loss_step=580.0, train_loss_epoch=592.0, val_loss_step=455.0]
# Epoch 9: 100% 588/588 [01:23<00:00,  7.02it/s, loss=578, v_num=0, val_loss_epoch=589.0, train_loss_step=580.0, train_loss_epoch=592.0, val_loss_step=455.0]
# Path to best model found during training:
# /content/outputs/2023-06-22/13-44-42/lightning_logs/version_0/checkpoints/9-2939.ckpt

# %%
# copy path file dari baris terakhir output cell di atas.

best_ssl_model_ckpt = "/content/outputs/2023-06-22/13-44-42/lightning_logs/version_0/checkpoints/9-2939.ckpt"

# %% [markdown]
# ### Supervised learning

# %%
# !python /content/saint/main.py experiment=supervised \
  experiment.model=saint \
  data.data_folder=/content/saint/data \
  data=bank_sup \
  experiment.pretrained_checkpoint={best_ssl_model_ckpt}
# Out:
# 2023-06-22 14:00:03.556900: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 14:00:05.032610: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/saint/main.py:11: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Global seed set to 1234
# Initializing supervised task using pretrained model:
# /content/outputs/2023-06-22/13-44-42/lightning_logs/version_0/checkpoints/9-2939.ckpt
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type             | Params
# --------------------------------------------------
# 0 | transformer  | Encoder          | 65.0 K
# 1 | embedding    | Embedding        | 3.2 K
# 2 | fc           | Linear           | 165
# 3 | criterion    | CrossEntropyLoss | 0
# 4 | train_metric | Accuracy         | 0
# 5 | valid_metric | Accuracy         | 0
# 6 | test_metric  | Accuracy         | 0
# --------------------------------------------------
# 68.3 K    Trainable params
# 0         Non-trainable params
# 68.3 K    Total params
# 0.273     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0:  77% 980/1272 [01:30<00:26, 10.85it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 0:  79% 1000/1272 [01:31<00:24, 10.99it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  80% 1020/1272 [01:31<00:22, 11.14it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  82% 1040/1272 [01:32<00:20, 11.29it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  83% 1060/1272 [01:32<00:18, 11.43it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  85% 1080/1272 [01:33<00:16, 11.58it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  86% 1100/1272 [01:33<00:14, 11.72it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  88% 1120/1272 [01:34<00:12, 11.86it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  90% 1140/1272 [01:35<00:11, 12.00it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  91% 1160/1272 [01:35<00:09, 12.13it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  93% 1180/1272 [01:36<00:07, 12.25it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  94% 1200/1272 [01:37<00:05, 12.36it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  96% 1220/1272 [01:37<00:04, 12.48it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  97% 1240/1272 [01:38<00:02, 12.60it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0:  99% 1260/1272 [01:39<00:00, 12.70it/s, loss=0.971, v_num=0, val_loss=1.690, val_acc_epoch=0.234, train_loss_step=0.925]
# Epoch 0: 100% 1272/1272 [01:39<00:00, 12.73it/s, loss=0.787, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.281, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  77% 980/1272 [01:31<00:27, 10.74it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 1:  79% 1000/1272 [01:31<00:25, 10.88it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  80% 1020/1272 [01:32<00:22, 11.03it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  82% 1040/1272 [01:33<00:20, 11.17it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  83% 1060/1272 [01:33<00:18, 11.32it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  85% 1080/1272 [01:34<00:16, 11.47it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  86% 1100/1272 [01:34<00:14, 11.61it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  88% 1120/1272 [01:35<00:12, 11.75it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  90% 1140/1272 [01:35<00:11, 11.89it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  91% 1160/1272 [01:36<00:09, 12.02it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  93% 1180/1272 [01:37<00:07, 12.16it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  94% 1200/1272 [01:37<00:05, 12.29it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  96% 1220/1272 [01:38<00:04, 12.43it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  97% 1240/1272 [01:38<00:02, 12.56it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1:  99% 1260/1272 [01:39<00:00, 12.69it/s, loss=0.975, v_num=0, val_loss=1.660, val_acc_epoch=0.335, train_loss_step=0.769, train_loss_epoch=1.330, train_acc_epoch=0.417]
# Epoch 1: 100% 1272/1272 [01:39<00:00, 12.75it/s, loss=0.78, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.345, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  77% 980/1272 [01:31<00:27, 10.68it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 2:  79% 1000/1272 [01:32<00:25, 10.79it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  80% 1020/1272 [01:33<00:23, 10.92it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  82% 1040/1272 [01:34<00:20, 11.05it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  83% 1060/1272 [01:34<00:18, 11.18it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  85% 1080/1272 [01:35<00:17, 11.28it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  86% 1100/1272 [01:36<00:15, 11.40it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  88% 1120/1272 [01:37<00:13, 11.54it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  90% 1140/1272 [01:37<00:11, 11.67it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  91% 1160/1272 [01:38<00:09, 11.81it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  93% 1180/1272 [01:38<00:07, 11.94it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  94% 1200/1272 [01:39<00:05, 12.07it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  96% 1220/1272 [01:39<00:04, 12.21it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  97% 1240/1272 [01:40<00:02, 12.33it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2:  99% 1260/1272 [01:41<00:00, 12.46it/s, loss=0.927, v_num=0, val_loss=1.540, val_acc_epoch=0.379, train_loss_step=0.771, train_loss_epoch=1.220, train_acc_epoch=0.480]
# Epoch 2: 100% 1272/1272 [01:41<00:00, 12.52it/s, loss=0.781, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=0.624, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  77% 980/1272 [01:32<00:27, 10.65it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 3:  79% 1000/1272 [01:32<00:25, 10.78it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  80% 1020/1272 [01:33<00:23, 10.93it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  82% 1040/1272 [01:33<00:20, 11.07it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  83% 1060/1272 [01:34<00:18, 11.22it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  85% 1080/1272 [01:35<00:16, 11.35it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  86% 1100/1272 [01:35<00:14, 11.48it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  88% 1120/1272 [01:36<00:13, 11.61it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  90% 1140/1272 [01:37<00:11, 11.72it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  91% 1160/1272 [01:37<00:09, 11.84it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  93% 1180/1272 [01:38<00:07, 11.96it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  94% 1200/1272 [01:39<00:05, 12.05it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  96% 1220/1272 [01:40<00:04, 12.15it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  97% 1240/1272 [01:41<00:02, 12.27it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3:  99% 1260/1272 [01:41<00:00, 12.40it/s, loss=0.986, v_num=0, val_loss=1.550, val_acc_epoch=0.378, train_loss_step=1.150, train_loss_epoch=1.190, train_acc_epoch=0.493]
# Epoch 3: 100% 1272/1272 [01:42<00:00, 12.46it/s, loss=0.818, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.257, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  77% 980/1272 [01:31<00:27, 10.68it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 4:  79% 1000/1272 [01:32<00:25, 10.82it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  80% 1020/1272 [01:32<00:22, 10.97it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  82% 1040/1272 [01:33<00:20, 11.12it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  83% 1060/1272 [01:34<00:18, 11.26it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  85% 1080/1272 [01:34<00:16, 11.40it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  86% 1100/1272 [01:35<00:14, 11.55it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  88% 1120/1272 [01:35<00:13, 11.69it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  90% 1140/1272 [01:36<00:11, 11.82it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  91% 1160/1272 [01:37<00:09, 11.96it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  93% 1180/1272 [01:37<00:07, 12.09it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  94% 1200/1272 [01:38<00:05, 12.23it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  96% 1220/1272 [01:38<00:04, 12.36it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  97% 1240/1272 [01:39<00:02, 12.48it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4:  99% 1260/1272 [01:40<00:00, 12.59it/s, loss=0.956, v_num=0, val_loss=1.540, val_acc_epoch=0.375, train_loss_step=0.834, train_loss_epoch=1.170, train_acc_epoch=0.500]
# Epoch 4: 100% 1272/1272 [01:40<00:00, 12.64it/s, loss=0.792, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.812, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  77% 980/1272 [01:33<00:27, 10.46it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 5:  79% 1000/1272 [01:34<00:25, 10.58it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  80% 1020/1272 [01:35<00:23, 10.73it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  82% 1040/1272 [01:35<00:21, 10.87it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  83% 1060/1272 [01:36<00:19, 11.01it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  85% 1080/1272 [01:36<00:17, 11.15it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  86% 1100/1272 [01:37<00:15, 11.29it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  88% 1120/1272 [01:38<00:13, 11.43it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  90% 1140/1272 [01:38<00:11, 11.56it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  91% 1160/1272 [01:39<00:09, 11.70it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  93% 1180/1272 [01:39<00:07, 11.83it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  94% 1200/1272 [01:40<00:06, 11.96it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  96% 1220/1272 [01:40<00:04, 12.09it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  97% 1240/1272 [01:41<00:02, 12.22it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5:  99% 1260/1272 [01:42<00:00, 12.34it/s, loss=1, v_num=0, val_loss=1.550, val_acc_epoch=0.373, train_loss_step=0.832, train_loss_epoch=1.160, train_acc_epoch=0.507]
# Epoch 5: 100% 1272/1272 [01:42<00:00, 12.40it/s, loss=0.766, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.682, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  77% 980/1272 [01:35<00:28, 10.31it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 6:  79% 1000/1272 [01:36<00:26, 10.41it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  80% 1020/1272 [01:36<00:23, 10.52it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  82% 1040/1272 [01:37<00:21, 10.65it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  83% 1060/1272 [01:38<00:19, 10.79it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  85% 1080/1272 [01:38<00:17, 10.93it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  86% 1100/1272 [01:39<00:15, 11.06it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  88% 1120/1272 [01:40<00:13, 11.20it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  90% 1140/1272 [01:40<00:11, 11.33it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  91% 1160/1272 [01:41<00:09, 11.46it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  93% 1180/1272 [01:41<00:07, 11.59it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  94% 1200/1272 [01:42<00:06, 11.72it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  96% 1220/1272 [01:42<00:04, 11.84it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  97% 1240/1272 [01:43<00:02, 11.97it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6:  99% 1260/1272 [01:44<00:00, 12.10it/s, loss=0.912, v_num=0, val_loss=1.560, val_acc_epoch=0.371, train_loss_step=0.678, train_loss_epoch=1.160, train_acc_epoch=0.508]
# Epoch 6: 100% 1272/1272 [01:44<00:00, 12.16it/s, loss=0.735, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.274, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  77% 980/1272 [01:33<00:27, 10.50it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 7:  79% 1000/1272 [01:34<00:25, 10.63it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  80% 1020/1272 [01:34<00:23, 10.76it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  82% 1040/1272 [01:35<00:21, 10.89it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  83% 1060/1272 [01:36<00:19, 11.01it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  85% 1080/1272 [01:36<00:17, 11.14it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  86% 1100/1272 [01:37<00:15, 11.25it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  88% 1120/1272 [01:38<00:13, 11.35it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  90% 1140/1272 [01:39<00:11, 11.47it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  91% 1160/1272 [01:39<00:09, 11.61it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  93% 1180/1272 [01:40<00:07, 11.74it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  94% 1200/1272 [01:41<00:06, 11.87it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  96% 1220/1272 [01:41<00:04, 12.00it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  97% 1240/1272 [01:42<00:02, 12.12it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7:  99% 1260/1272 [01:42<00:00, 12.25it/s, loss=0.933, v_num=0, val_loss=1.580, val_acc_epoch=0.370, train_loss_step=0.964, train_loss_epoch=1.150, train_acc_epoch=0.515]
# Epoch 7: 100% 1272/1272 [01:43<00:00, 12.30it/s, loss=0.763, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.269, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  77% 980/1272 [01:34<00:28, 10.42it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 8:  79% 1000/1272 [01:34<00:25, 10.55it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  80% 1020/1272 [01:35<00:23, 10.70it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  82% 1040/1272 [01:35<00:21, 10.85it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  83% 1060/1272 [01:36<00:19, 10.99it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  85% 1080/1272 [01:37<00:17, 11.11it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  86% 1100/1272 [01:37<00:15, 11.23it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  88% 1120/1272 [01:38<00:13, 11.35it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  90% 1140/1272 [01:39<00:11, 11.47it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  91% 1160/1272 [01:40<00:09, 11.59it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  93% 1180/1272 [01:40<00:07, 11.68it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  94% 1200/1272 [01:41<00:06, 11.78it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  96% 1220/1272 [01:42<00:04, 11.91it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  97% 1240/1272 [01:43<00:02, 12.04it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8:  99% 1260/1272 [01:43<00:00, 12.16it/s, loss=0.966, v_num=0, val_loss=1.550, val_acc_epoch=0.383, train_loss_step=0.875, train_loss_epoch=1.150, train_acc_epoch=0.516]
# Epoch 8: 100% 1272/1272 [01:44<00:00, 12.23it/s, loss=0.742, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.288, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  77% 980/1272 [01:32<00:27, 10.57it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/294 [00:00<?, ?it/s]
# Epoch 9:  79% 1000/1272 [01:33<00:25, 10.71it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  80% 1020/1272 [01:33<00:23, 10.85it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  82% 1040/1272 [01:34<00:21, 11.00it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  83% 1060/1272 [01:35<00:19, 11.14it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  85% 1080/1272 [01:35<00:17, 11.28it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  86% 1100/1272 [01:36<00:15, 11.42it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  88% 1120/1272 [01:36<00:13, 11.56it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  90% 1140/1272 [01:37<00:11, 11.70it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  91% 1160/1272 [01:38<00:09, 11.83it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  93% 1180/1272 [01:38<00:07, 11.97it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  94% 1200/1272 [01:39<00:05, 12.09it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  96% 1220/1272 [01:40<00:04, 12.20it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  97% 1240/1272 [01:40<00:02, 12.31it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9:  99% 1260/1272 [01:41<00:00, 12.42it/s, loss=0.901, v_num=0, val_loss=1.570, val_acc_epoch=0.378, train_loss_step=0.940, train_loss_epoch=1.140, train_acc_epoch=0.518]
# Epoch 9: 100% 1272/1272 [01:42<00:00, 12.46it/s, loss=0.785, v_num=0, val_loss=1.520, val_acc_epoch=0.394, train_loss_step=0.771, train_loss_epoch=1.140, train_acc_epoch=0.520]
# Epoch 9: 100% 1272/1272 [01:42<00:00, 12.45it/s, loss=0.785, v_num=0, val_loss=1.520, val_acc_epoch=0.394, train_loss_step=0.771, train_loss_epoch=1.140, train_acc_epoch=0.520]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 100% 391/391 [00:12<00:00, 32.45it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_acc_best_epoch': 0.40913090109825134, 'test_loss': 1.4946136474609375}
# --------------------------------------------------------------------------------
# Path to best model found during training:
# /content/outputs/2023-06-22/14-00-07/lightning_logs/version_0/checkpoints/9-9779.ckpt

# %% [markdown]
# ## Supervised learning only

# %%
# bare SUP

# !python /content/saint/main.py experiment=supervised \
  experiment.model=saint \
  data.data_folder=/content/saint/data \
  data=bank_sup
# Out:
# 2023-06-22 08:36:17.143745: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 08:36:18.588804: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/saint/main.py:11: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Global seed set to 1234
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:36: UserWarning: Metric `AUROC` will save all targets and predictions in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type             | Params
# --------------------------------------------------
# 0 | transformer  | Encoder          | 65.0 K
# 1 | embedding    | Embedding        | 3.2 K
# 2 | fc           | Linear           | 165
# 3 | criterion    | CrossEntropyLoss | 0
# 4 | train_metric | AUROC            | 0
# --------------------------------------------------
# 68.3 K    Trainable params
# 0         Non-trainable params
# 68.3 K    Total params
# 0.273     Total estimated model params size (MB)
# Global seed set to 1234
# Epoch 0: 100% 2/2 [00:00<00:00,  8.45it/s]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 0: 100% 2/2 [00:00<00:00,  4.82it/s, loss=1.71, v_num=0, val_loss=1.700, val_auroc_epoch=0.736, train_loss_step=1.710, train_loss_epoch=1.710, train_auroc_epoch=0.593]
# Epoch 1: 100% 2/2 [00:00<00:00,  8.94it/s, loss=1.71, v_num=0, val_loss=1.700, val_auroc_epoch=0.736, train_loss_step=1.710, train_loss_epoch=1.710, train_auroc_epoch=0.593]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 1: 100% 2/2 [00:00<00:00,  4.96it/s, loss=1.73, v_num=0, val_loss=1.690, val_auroc_epoch=0.734, train_loss_step=1.740, train_loss_epoch=1.740, train_auroc_epoch=0.473]
# Epoch 2: 100% 2/2 [00:00<00:00,  8.49it/s, loss=1.73, v_num=0, val_loss=1.690, val_auroc_epoch=0.734, train_loss_step=1.740, train_loss_epoch=1.740, train_auroc_epoch=0.473]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 2: 100% 2/2 [00:00<00:00,  4.79it/s, loss=1.75, v_num=0, val_loss=1.680, val_auroc_epoch=0.741, train_loss_step=1.790, train_loss_epoch=1.790, train_auroc_epoch=0.393]
# Epoch 3: 100% 2/2 [00:00<00:00,  8.72it/s, loss=1.75, v_num=0, val_loss=1.680, val_auroc_epoch=0.741, train_loss_step=1.790, train_loss_epoch=1.790, train_auroc_epoch=0.393]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 3: 100% 2/2 [00:00<00:00,  4.88it/s, loss=1.73, v_num=0, val_loss=1.670, val_auroc_epoch=0.741, train_loss_step=1.690, train_loss_epoch=1.690, train_auroc_epoch=0.483]
# Epoch 4: 100% 2/2 [00:00<00:00,  8.54it/s, loss=1.73, v_num=0, val_loss=1.670, val_auroc_epoch=0.741, train_loss_step=1.690, train_loss_epoch=1.690, train_auroc_epoch=0.483]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 4: 100% 2/2 [00:00<00:00,  4.77it/s, loss=1.73, v_num=0, val_loss=1.660, val_auroc_epoch=0.736, train_loss_step=1.720, train_loss_epoch=1.720, train_auroc_epoch=0.463]
# Epoch 5: 100% 2/2 [00:00<00:00,  8.46it/s, loss=1.73, v_num=0, val_loss=1.660, val_auroc_epoch=0.736, train_loss_step=1.720, train_loss_epoch=1.720, train_auroc_epoch=0.463]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 5: 100% 2/2 [00:00<00:00,  4.68it/s, loss=1.74, v_num=0, val_loss=1.650, val_auroc_epoch=0.730, train_loss_step=1.780, train_loss_epoch=1.780, train_auroc_epoch=0.325]
# Epoch 6: 100% 2/2 [00:00<00:00,  8.04it/s, loss=1.74, v_num=0, val_loss=1.650, val_auroc_epoch=0.730, train_loss_step=1.780, train_loss_epoch=1.780, train_auroc_epoch=0.325]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 6: 100% 2/2 [00:00<00:00,  4.56it/s, loss=1.71, v_num=0, val_loss=1.640, val_auroc_epoch=0.749, train_loss_step=1.560, train_loss_epoch=1.560, train_auroc_epoch=0.581]
# Epoch 7: 100% 2/2 [00:00<00:00,  8.76it/s, loss=1.71, v_num=0, val_loss=1.640, val_auroc_epoch=0.749, train_loss_step=1.560, train_loss_epoch=1.560, train_auroc_epoch=0.581]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 7: 100% 2/2 [00:00<00:00,  4.81it/s, loss=1.71, v_num=0, val_loss=1.640, val_auroc_epoch=0.759, train_loss_step=1.660, train_loss_epoch=1.660, train_auroc_epoch=0.531]
# Epoch 8: 100% 2/2 [00:00<00:00,  8.62it/s, loss=1.71, v_num=0, val_loss=1.640, val_auroc_epoch=0.759, train_loss_step=1.660, train_loss_epoch=1.660, train_auroc_epoch=0.531]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 8: 100% 2/2 [00:00<00:00,  4.75it/s, loss=1.69, v_num=0, val_loss=1.630, val_auroc_epoch=0.752, train_loss_step=1.600, train_loss_epoch=1.600, train_auroc_epoch=0.574]
# Epoch 9: 100% 2/2 [00:00<00:00,  8.46it/s, loss=1.69, v_num=0, val_loss=1.630, val_auroc_epoch=0.752, train_loss_step=1.600, train_loss_epoch=1.600, train_auroc_epoch=0.574]
# Validating: 0it [00:00, ?it/s]
# Validating:   0% 0/1 [00:00<?, ?it/s]
# Epoch 9: 100% 2/2 [00:00<00:00,  4.85it/s, loss=1.69, v_num=0, val_loss=1.630, val_auroc_epoch=0.752, train_loss_step=1.670, train_loss_epoch=1.670, train_auroc_epoch=0.489]
# Epoch 9: 100% 2/2 [00:00<00:00,  4.23it/s, loss=1.69, v_num=0, val_loss=1.630, val_auroc_epoch=0.752, train_loss_step=1.670, train_loss_epoch=1.670, train_auroc_epoch=0.489]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: 100% 1/1 [00:00<00:00,  5.34it/s]
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_auroc_best_epoch': 0.597684383392334, 'test_loss': 1.5236207246780396}
# --------------------------------------------------------------------------------
# Path to best model found during training:
# /content/outputs/2023-06-22/08-36-21/lightning_logs/version_0/checkpoints/9-9.ckpt

# %% [markdown]
# # Evaluation

# %%
pretrained_checkpoint = "/content/outputs/2023-06-22/14-00-07/lightning_logs/version_0/checkpoints/9-9779.ckpt"

# %%
# !python /content/saint/predict.py experiment=predict \
  experiment.model=saint \
  data=bank_sup \
  data.data_folder=/content/saint/data \
  experiment.pretrained_checkpoint={pretrained_checkpoint} \
  experiment.pred_sav_path=/content/predict.csv
# Out:
# 2023-06-22 14:22:13.095377: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 14:22:14.110517: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /content/saint/predict.py:15: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="config")
# /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# {'seed': 1234, 'transformer': {'num_layers': 6, 'num_heads': 8, 'dropout': 0.1, 'dropout_ff': 0.1, 'embed_dim': 32, 'd_ff': 32, 'cls_token_idx': 0}, 'augmentation': {'prob_cutmix': 0.3, 'alpha': 0.2, 'lambda_pt': 10}, 'optimizer': {'temperature': 0.7, 'proj_head_dim': 128, 'beta_1': 0.9, 'beta_2': 0.99, 'lr': 0.0001, 'weight_decay': 0.01, 'optim': 'adamw', 'metric': 'acc'}, 'preproc': {'data_folder': None, 'train_split': 0.65, 'validation_split': 0.15, 'test_split': 0.2, 'num_supervised_train_data': None}, 'callback': {'monitor': 'val_loss', 'mode': 'min', 'auto_insert_metric_name': False}, 'trainer': {'max_epochs': 10, 'gpus': 1, 'deterministic': True, 'default_root_dir': None, 'resume_from_checkpoint': None}, 'dataloader': {'shuffle_val': False, 'train_bs': 32, 'val_bs': 32, 'test_bs': 16, 'num_workers': 2, 'pin_memory': False}, 'metric': '${optimizer.metric}', 'print_config': False, 'experiment': {'model': 'saint', 'task': 'classification', 'pretrained_checkpoint': '/content/outputs/2023-06-22/14-00-07/lightning_logs/version_0/checkpoints/9-9779.ckpt', 'num_output': 5, 'pred_sav_path': '/content/predict.csv', 'save_prediction': True, 'id_col': 'index', 'target_col': 'target'}, 'data': {'data_folder': '/content/saint/data', 'data_paths': {'train_csv_path': '${data.data_folder}/train.csv', 'train_y_csv_path': '${data.data_folder}/train_y.csv', 'val_csv_path': '${data.data_folder}/val.csv', 'val_y_csv_path': '${data.data_folder}/val_y.csv', 'test_csv_path': '${data.data_folder}/test.csv', 'test_y_csv_path': '${data.data_folder}/test_y.csv'}, 'data_stats': {'no_cat': 1, 'no_num': 49, 'cats': [1]}}}
# Prediction finished,  csv saved at /content/predict.csv

# %%
pred = pd.read_csv("/content/predict.csv")
pred['target'].value_counts()
# Out:
# 3    8739
# 1    3304
# 4     331
# 2      87
# 0      46
# Name: target, dtype: int64

# %%
y_truth = pd.read_csv("/content/saint/data/test_y.csv")
y_truth['EST9'].value_counts()
# Out:
# 3    3599
# 1    2795
# 2    2591
# 4    2040
# 0    1482
# Name: EST9, dtype: int64

# %%
print(classification_report(y_truth, pred['target'], digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8696    0.0270    0.0524      1482
#            1     0.4268    0.5045    0.4624      2795
#            2     0.4828    0.0162    0.0314      2591
#            3     0.3811    0.9253    0.5398      3599
#            4     0.8912    0.1446    0.2488      2040
#
#     accuracy                         0.4091     12507
#    macro avg     0.6103    0.3235    0.2669     12507
# weighted avg     0.5534    0.4091    0.3119     12507

# %%
cm = confusion_matrix(y_truth, pred['target'])
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
# Out:
# <Axes: >
